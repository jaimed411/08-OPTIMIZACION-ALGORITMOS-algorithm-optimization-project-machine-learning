# %% [markdown]
# # Optimization of Algorithms problems

# %% [markdown]
# ## Exercise 1: Optimization of a library management system
#
# You are provided with a code that simulates a library management system. The system has the ability to add books to the library, lend books to readers, and receive books back. In addition, it can also list all the books available in the library.
#
# The problem is that the system is very slow and needs to be optimized. Your task is to analyze the code, identify areas of improvement and rewrite parts of the code to make it more efficient. Specifically, you are asked to perform the following improvements (update the below code and implement the following points):
#
# 1. Identify and improve the data structures used to store books in the library and borrowed books. *Hint: Use an `set` instead of a `list` to store books in `Library.books` and `Library.borrowed_books` to make it more efficient to check if a book is present.**
#
# 2. Avoid errors that could occur when attempting to borrow or return a book that is not present. *Hint: Use the `set.discard()` method instead of `list.remove()` in `Library.borrow_book()` and `Library.return_book()` to avoid errors if the book is not present.*
#
# 3. Improve the efficiency of selecting a random book to lend or return. *Hint: Instead of selecting a random book from `Library.books` or `Library.borrowed_books` by indexing (which involves a conversion to list which is expensive), you can convert these sets to lists only once before the cycle.*
#
# 4. Improve the efficiency of the function that lists all the books available in the library. *Hint: Instead of printing each book one by one in `Library.list_books()`, you can construct a complete string with all book titles and then print that string once.*
#
# 5. Avoid repeated calls to `len()` in the body of loops.
#
# 6. Use list comprehension to improve efficiency of book creation.. *Hint: Use list comprehension for book creation, which can be faster than using a for loop and repeatedly calling `Library.add_book()`.*
#
# 7. Optimize checking the availability of borrowed books before attempting to return them. *Hint: Avoid checking `if library.borrowed_books:` before attempting to return a book. If you use sets and the `discard()` method, there is no need for this check.*

# %% [markdown]
# #### Read and update the following given code:

# %%
import random
import time

class Book:
    def __init__(self, title, author, pages):
        self.title = title
        self.author = author
        self.pages = pages

class Library:
    def __init__(self, name):
        self.name = name
        self.books = set()  # Paso 1: Usar un conjunto en lugar de una lista
        self.borrowed_books = set()  # Paso 1: Usar un conjunto en lugar de una lista

    def add_book(self, book):
        if book not in self.books:
            self.books.add(book)
            print("Este libro no ha sido añadido. Lo añadiremos a la lista.")
        else:
            print("Este libro ya está añadido. Reemplazaremos el ejemplar que había por uno nuevo.")

    def borrow_book(self, book):
        if book in self.books:
            self.books.discard(book)  # Paso 2: Usar el método discard() en lugar de remove()
            self.borrowed_books.add(book)
            print("Este libro existe y se va a alquilar.")
            return True
        else:
            print("Este libro no existe y no se puede alquilar.")
            return False

    def return_book(self, book):
        if book in self.borrowed_books:
            self.borrowed_books.discard(book)  # Paso 2: Usar el método discard() en lugar de remove()
            self.books.add(book)
            print("Este libro estaba alquilado y se procede a su devolución.")
            return True
        else:
            print("El libro ya aparece devuelto. Observar si hay error.")
            return False

    def list_books(self):
        book_titles = [book.title for book in self.books]  # Paso 4: Usar list comprehension para construir una lista de títulos
        book_titles_string = '\n'.join(book_titles)  # Paso 4: Unir todos los títulos en una sola cadena
        print(book_titles_string)

# Create a library
library = Library("Codeville")

# Add some books using list comprehension
books = [Book(f"Book {i}", f"Author {i}", i*10) for i in range(1, 101)]  # Paso 6: Usar list comprehension para crear los libros
library.books.update(books)  # Paso 6: Agregar todos los libros al conjunto directamente

# Borrow some books
book_list = list(library.books)  # Paso 3: Convertir el conjunto de libros a una lista
for _ in range(50):
    book_to_borrow = random.choice(book_list)  # Paso 3: Seleccionar un libro aleatorio de la lista
    library.borrow_book(book_to_borrow)

# Return some books
borrowed_books_list = list(library.borrowed_books)  # Paso 3: Convertir el conjunto de libros prestados a una lista
for _ in range(25):
    book_to_return = random.choice(borrowed_books_list)  # Paso 3: Seleccionar un libro aleatorio de la lista
    library.return_book(book_to_return)
    borrowed_books_list.remove(book_to_return)  # Paso 7: Eliminar el libro devuelto de la lista directamente

# List all the books
start_time = time.time()
library.list_books()
end_time = time.time()

print(f"Listing took {end_time - start_time} seconds")  # Paso 5: Evitar llamadas repetidas a len()
# Out:
# Este libro existe y se va a alquilar.
# Este libro existe y se va a alquilar.
# Este libro existe y se va a alquilar.
# Este libro existe y se va a alquilar.
# Este libro existe y se va a alquilar.
# Este libro existe y se va a alquilar.
# Este libro existe y se va a alquilar.
# Este libro existe y se va a alquilar.
# Este libro existe y se va a alquilar.
# Este libro existe y se va a alquilar.
# Este libro existe y se va a alquilar.
# Este libro existe y se va a alquilar.
# Este libro existe y se va a alquilar.
# Este libro existe y se va a alquilar.
# Este libro existe y se va a alquilar.
# Este libro no existe y no se puede alquilar.
# Este libro existe y se va a alquilar.
# Este libro existe y se va a alquilar.
# Este libro existe y se va a alquilar.
# Este libro no existe y no se puede alquilar.
# Este libro existe y se va a alquilar.
# Este libro no existe y no se puede alquilar.
# Este libro existe y se va a alquilar.
# Este libro existe y se va a alquilar.
# Este libro existe y se va a alquilar.
# Este libro no existe y no se puede alquilar.
# Este libro existe y se va a alquilar.
# Este libro existe y se va a alquilar.
# Este libro existe y se va a alquilar.
# Este libro existe y se va a alquilar.
# Este libro no existe y no se puede alquilar.
# Este libro no existe y no se puede alquilar.
# Este libro existe y se va a alquilar.
# Este libro no existe y no se puede alquilar.
# Este libro no existe y no se puede alquilar.
# Este libro existe y se va a alquilar.
# Este libro existe y se va a alquilar.
# Este libro no existe y no se puede alquilar.
# Este libro no existe y no se puede alquilar.
# Este libro existe y se va a alquilar.
# Este libro no existe y no se puede alquilar.
# Este libro existe y se va a alquilar.
# Este libro existe y se va a alquilar.
# Este libro existe y se va a alquilar.
# Este libro existe y se va a alquilar.
# Este libro existe y se va a alquilar.
# Este libro existe y se va a alquilar.
# Este libro existe y se va a alquilar.
# Este libro existe y se va a alquilar.
# Este libro existe y se va a alquilar.
# Este libro estaba alquilado y se procede a su devolución.
# Este libro estaba alquilado y se procede a su devolución.
# Este libro estaba alquilado y se procede a su devolución.
# Este libro estaba alquilado y se procede a su devolución.
# Este libro estaba alquilado y se procede a su devolución.
# Este libro estaba alquilado y se procede a su devolución.
# Este libro estaba alquilado y se procede a su devolución.
# Este libro estaba alquilado y se procede a su devolución.
# Este libro estaba alquilado y se procede a su devolución.
# Este libro estaba alquilado y se procede a su devolución.
# Este libro estaba alquilado y se procede a su devolución.
# Este libro estaba alquilado y se procede a su devolución.
# Este libro estaba alquilado y se procede a su devolución.
# Este libro estaba alquilado y se procede a su devolución.
# Este libro estaba alquilado y se procede a su devolución.
# Este libro estaba alquilado y se procede a su devolución.
# Este libro estaba alquilado y se procede a su devolución.
# Este libro estaba alquilado y se procede a su devolución.
# Este libro estaba alquilado y se procede a su devolución.
# Este libro estaba alquilado y se procede a su devolución.
# Este libro estaba alquilado y se procede a su devolución.
# Este libro estaba alquilado y se procede a su devolución.
# Este libro estaba alquilado y se procede a su devolución.
# Este libro estaba alquilado y se procede a su devolución.
# Este libro estaba alquilado y se procede a su devolución.
# Book 3
# Book 13
# Book 26
# Book 76
# Book 37
# Book 30
# Book 83
# Book 77
# Book 85
# Book 86
# Book 5
# Book 40
# Book 88
# Book 41
# Book 42
# Book 87
# Book 43
# Book 78
# Book 1
# Book 89
# Book 45
# Book 44
# Book 50
# Book 91
# Book 100
# Book 4
# Book 46
# Book 93
# Book 49
# Book 10
# Book 7
# Book 81
# Book 9
# Book 51
# Book 95
# Book 8
# Book 52
# Book 53
# Book 12
# Book 97
# Book 54
# Book 2
# Book 14
# Book 55
# Book 92
# Book 16
# Book 99
# Book 56
# Book 18
# Book 57
# Book 20
# Book 58
# Book 59
# Book 21
# Book 94
# Book 60
# Book 23
# Book 15
# Book 61
# Book 11
# Book 90
# Book 62
# Book 6
# Book 63
# Book 64
# Book 24
# Book 84
# Book 65
# Book 25
# Book 66
# Book 67
# Book 27
# Book 19
# Book 69
# Book 70
# Book 17
# Book 29
# Book 71
# Book 79
# Book 31
# Book 72
# Book 32
# Book 73
# Book 38
# Book 33
# Book 35
# Listing took 8.368492126464844e-05 seconds

# %% [markdown]
# ## Exercise 2: Task Management System Optimization
#
# You are provided with code that simulates a task management system. The system has the ability to add tasks, mark tasks as completed and list all tasks along with their status.
#
# As in the first exercise, the system is quite slow and needs to be optimized. Your task is to analyze the code, identify areas that could be improved, and rewrite parts of the code to make it more efficient. Specifically, you are asked to perform the following tasks:
#
# 1. Identify and improve the data structures used to store the tasks. *Hint: Use an `set` or `dict` instead of a `list` to store tasks in `TaskManager`, to make checking for the existence of a task more efficient.*
#
# 2. Avoid checking whether a task is in the task list each time a task is completed. *Hint: Avoid checking for the existence of a task in `TaskManager.complete_task()`. If you are sure that the task comes from `TaskManager.tasks`, it is not necessary to check if it is in the list.*
#
# 3. Restructure the way task status is tracked. *Hint: Instead of marking a task as completed by modifying its `is_done` attribute, you may consider having two sets or lists in `TaskManager`: one for pending tasks and one for completed tasks.*
#
# 4. Use list comprehension to improve the efficiency of task creation. *Hint: Use a list comprehension for task creation, which may be faster than using a for loop and repeatedly calling `TaskManager.add_task()`.*
#
# 5. Improve the efficiency of the function that lists all tasks. *Hint: Instead of printing each task one by one in `TaskManager.list_tasks()`, you can build a complete string with all tasks and then print that string once.*
#
# 6. Introduce an `id` attribute to uniquely identify each task. *Hint: Consider using an `id` attribute on the `Task` class to uniquely identify each task. This can make it easier to find and manage tasks.*
#
# 7. Avoid repeated calls to the same function or method in a loop. *Hint: Avoid repeatedly calling the same function or method in a loop, such as `TaskManager.add_task()` or `TaskManager.complete_task()`.*
#
# 8. Avoid repetition of code when calculating the status of a task. *Hint: Avoid code repetition. In `TaskManager.list_tasks()`, the task status is calculated the same way for each task. You may consider adding a method to the `Task` class that returns the status as a string.*
#
# 9. Improve code readability by using descriptive variable names. *Hint: Improve code readability by using descriptive variable names.*
#
# 10. Changes the way tasks are iterated over. *Hint: Instead of looping over a range of numbers and then indexing the list of tasks, you can iterate directly over the tasks.*

# %% [markdown]
# #### Read and update the following given code:

# %%
class Task:
    def __init__(self, task_id, description):  # 6. Introduce un atributo 'id' para identificar de forma única cada tarea.
        self.task_id = task_id
        self.description = description
        self.is_done = False

    def mark_as_done(self):
        self.is_done = True

    def get_status(self):  # 8. Evita la repetición de código al calcular el estado de una tarea..
        return "Hecha" if self.is_done else "Pendiente"


class TaskManager:
    def __init__(self):
        self.pending_tasks = set()  # 3. Reestructura la forma en que se realiza el seguimiento del estado de las tareas.
        self.completed_tasks = set()

    def add_task(self, task):
        self.pending_tasks.add(task)

    def complete_task(self, task):
        self.pending_tasks.remove(task)  # 2. Evita verificar si una tarea está en la lista de tareas cada vez que se completa una tarea.
        self.completed_tasks.add(task)

    def list_tasks(self):
        task_list = []
        for task in self.pending_tasks:
            task_list.append(f"TAREA: {task.description}, ESTADO: {task.get_status()}")
        for task in self.completed_tasks:
            task_list.append(f"TAREA: {task.description}, ESTADO: {task.get_status()}")
        print('\n'.join(task_list))  # 5. Mejora la eficiencia de la función que lista todas las tareas.

# Create a TaskManager
manager = TaskManager()

# Add some tasks
tasks = [Task(i, f"Tarea {i}") for i in range(1, 1001)]  # 4. Utiliza comprensión de listas para mejorar la eficiencia de la creación de tareas.
manager.pending_tasks.update(tasks)  # 7. Evita llamadas repetidas a la misma función o método en un bucle/loop.

# Complete some tasks
tasks_to_complete = list(manager.pending_tasks)  # Hace una copia del conjunto
for task in tasks_to_complete:  # 10. Cambia la forma en que se iteran las tareas.
    if task.task_id <= 500:
        manager.complete_task(task)

# List all the tasks
manager.list_tasks()
# Out:
# TAREA: Tarea 797, ESTADO: Pendiente
# TAREA: Tarea 920, ESTADO: Pendiente
# TAREA: Tarea 801, ESTADO: Pendiente
# TAREA: Tarea 921, ESTADO: Pendiente
# TAREA: Tarea 723, ESTADO: Pendiente
# TAREA: Tarea 774, ESTADO: Pendiente
# TAREA: Tarea 796, ESTADO: Pendiente
# TAREA: Tarea 922, ESTADO: Pendiente
# TAREA: Tarea 613, ESTADO: Pendiente
# TAREA: Tarea 923, ESTADO: Pendiente
# TAREA: Tarea 722, ESTADO: Pendiente
# TAREA: Tarea 924, ESTADO: Pendiente
# TAREA: Tarea 621, ESTADO: Pendiente
# TAREA: Tarea 725, ESTADO: Pendiente
# TAREA: Tarea 800, ESTADO: Pendiente
# TAREA: Tarea 925, ESTADO: Pendiente
# TAREA: Tarea 799, ESTADO: Pendiente
# TAREA: Tarea 926, ESTADO: Pendiente
# TAREA: Tarea 802, ESTADO: Pendiente
# TAREA: Tarea 803, ESTADO: Pendiente
# TAREA: Tarea 927, ESTADO: Pendiente
# TAREA: Tarea 777, ESTADO: Pendiente
# TAREA: Tarea 798, ESTADO: Pendiente
# TAREA: Tarea 636, ESTADO: Pendiente
# TAREA: Tarea 642, ESTADO: Pendiente
# TAREA: Tarea 928, ESTADO: Pendiente
# TAREA: Tarea 628, ESTADO: Pendiente
# TAREA: Tarea 806, ESTADO: Pendiente
# TAREA: Tarea 929, ESTADO: Pendiente
# TAREA: Tarea 804, ESTADO: Pendiente
# TAREA: Tarea 930, ESTADO: Pendiente
# TAREA: Tarea 649, ESTADO: Pendiente
# TAREA: Tarea 805, ESTADO: Pendiente
# TAREA: Tarea 931, ESTADO: Pendiente
# TAREA: Tarea 932, ESTADO: Pendiente
# TAREA: Tarea 807, ESTADO: Pendiente
# TAREA: Tarea 933, ESTADO: Pendiente
# TAREA: Tarea 810, ESTADO: Pendiente
# TAREA: Tarea 934, ESTADO: Pendiente
# TAREA: Tarea 808, ESTADO: Pendiente
# TAREA: Tarea 935, ESTADO: Pendiente
# TAREA: Tarea 645, ESTADO: Pendiente
# TAREA: Tarea 809, ESTADO: Pendiente
# TAREA: Tarea 743, ESTADO: Pendiente
# TAREA: Tarea 936, ESTADO: Pendiente
# TAREA: Tarea 614, ESTADO: Pendiente
# TAREA: Tarea 811, ESTADO: Pendiente
# TAREA: Tarea 937, ESTADO: Pendiente
# TAREA: Tarea 938, ESTADO: Pendiente
# TAREA: Tarea 812, ESTADO: Pendiente
# TAREA: Tarea 662, ESTADO: Pendiente
# TAREA: Tarea 939, ESTADO: Pendiente
# TAREA: Tarea 940, ESTADO: Pendiente
# TAREA: Tarea 813, ESTADO: Pendiente
# TAREA: Tarea 941, ESTADO: Pendiente
# TAREA: Tarea 814, ESTADO: Pendiente
# TAREA: Tarea 942, ESTADO: Pendiente
# TAREA: Tarea 815, ESTADO: Pendiente
# TAREA: Tarea 633, ESTADO: Pendiente
# TAREA: Tarea 943, ESTADO: Pendiente
# TAREA: Tarea 713, ESTADO: Pendiente
# TAREA: Tarea 816, ESTADO: Pendiente
# TAREA: Tarea 944, ESTADO: Pendiente
# TAREA: Tarea 817, ESTADO: Pendiente
# TAREA: Tarea 945, ESTADO: Pendiente
# TAREA: Tarea 818, ESTADO: Pendiente
# TAREA: Tarea 946, ESTADO: Pendiente
# TAREA: Tarea 819, ESTADO: Pendiente
# TAREA: Tarea 947, ESTADO: Pendiente
# TAREA: Tarea 820, ESTADO: Pendiente
# TAREA: Tarea 948, ESTADO: Pendiente
# TAREA: Tarea 821, ESTADO: Pendiente
# TAREA: Tarea 949, ESTADO: Pendiente
# TAREA: Tarea 620, ESTADO: Pendiente
# TAREA: Tarea 822, ESTADO: Pendiente
# TAREA: Tarea 648, ESTADO: Pendiente
# TAREA: Tarea 950, ESTADO: Pendiente
# TAREA: Tarea 823, ESTADO: Pendiente
# TAREA: Tarea 951, ESTADO: Pendiente
# TAREA: Tarea 824, ESTADO: Pendiente
# TAREA: Tarea 952, ESTADO: Pendiente
# TAREA: Tarea 825, ESTADO: Pendiente
# TAREA: Tarea 953, ESTADO: Pendiente
# TAREA: Tarea 615, ESTADO: Pendiente
# TAREA: Tarea 660, ESTADO: Pendiente
# TAREA: Tarea 826, ESTADO: Pendiente
# TAREA: Tarea 954, ESTADO: Pendiente
# TAREA: Tarea 631, ESTADO: Pendiente
# TAREA: Tarea 827, ESTADO: Pendiente
# TAREA: Tarea 955, ESTADO: Pendiente
# TAREA: Tarea 828, ESTADO: Pendiente
# TAREA: Tarea 956, ESTADO: Pendiente
# TAREA: Tarea 829, ESTADO: Pendiente
# TAREA: Tarea 664, ESTADO: Pendiente
# TAREA: Tarea 957, ESTADO: Pendiente
# TAREA: Tarea 830, ESTADO: Pendiente
# TAREA: Tarea 958, ESTADO: Pendiente
# TAREA: Tarea 831, ESTADO: Pendiente
# TAREA: Tarea 610, ESTADO: Pendiente
# TAREA: Tarea 959, ESTADO: Pendiente
# TAREA: Tarea 663, ESTADO: Pendiente
# TAREA: Tarea 832, ESTADO: Pendiente
# TAREA: Tarea 960, ESTADO: Pendiente
# TAREA: Tarea 833, ESTADO: Pendiente
# TAREA: Tarea 961, ESTADO: Pendiente
# TAREA: Tarea 640, ESTADO: Pendiente
# TAREA: Tarea 834, ESTADO: Pendiente
# TAREA: Tarea 609, ESTADO: Pendiente
# TAREA: Tarea 962, ESTADO: Pendiente
# TAREA: Tarea 650, ESTADO: Pendiente
# TAREA: Tarea 835, ESTADO: Pendiente
# TAREA: Tarea 742, ESTADO: Pendiente
# TAREA: Tarea 963, ESTADO: Pendiente
# TAREA: Tarea 657, ESTADO: Pendiente
# TAREA: Tarea 836, ESTADO: Pendiente
# TAREA: Tarea 964, ESTADO: Pendiente
# TAREA: Tarea 837, ESTADO: Pendiente
# TAREA: Tarea 619, ESTADO: Pendiente
# TAREA: Tarea 965, ESTADO: Pendiente
# TAREA: Tarea 838, ESTADO: Pendiente
# TAREA: Tarea 966, ESTADO: Pendiente
# TAREA: Tarea 653, ESTADO: Pendiente
# TAREA: Tarea 839, ESTADO: Pendiente
# TAREA: Tarea 967, ESTADO: Pendiente
# TAREA: Tarea 729, ESTADO: Pendiente
# TAREA: Tarea 840, ESTADO: Pendiente
# TAREA: Tarea 656, ESTADO: Pendiente
# TAREA: Tarea 968, ESTADO: Pendiente
# TAREA: Tarea 841, ESTADO: Pendiente
# TAREA: Tarea 969, ESTADO: Pendiente
# TAREA: Tarea 842, ESTADO: Pendiente
# TAREA: Tarea 776, ESTADO: Pendiente
# TAREA: Tarea 970, ESTADO: Pendiente
# TAREA: Tarea 843, ESTADO: Pendiente
# TAREA: Tarea 655, ESTADO: Pendiente
# TAREA: Tarea 971, ESTADO: Pendiente
# TAREA: Tarea 844, ESTADO: Pendiente
# TAREA: Tarea 669, ESTADO: Pendiente
# TAREA: Tarea 972, ESTADO: Pendiente
# TAREA: Tarea 845, ESTADO: Pendiente
# TAREA: Tarea 626, ESTADO: Pendiente
# TAREA: Tarea 973, ESTADO: Pendiente
# TAREA: Tarea 846, ESTADO: Pendiente
# TAREA: Tarea 654, ESTADO: Pendiente
# TAREA: Tarea 974, ESTADO: Pendiente
# TAREA: Tarea 622, ESTADO: Pendiente
# TAREA: Tarea 667, ESTADO: Pendiente
# TAREA: Tarea 847, ESTADO: Pendiente
# TAREA: Tarea 716, ESTADO: Pendiente
# TAREA: Tarea 975, ESTADO: Pendiente
# TAREA: Tarea 848, ESTADO: Pendiente
# TAREA: Tarea 976, ESTADO: Pendiente
# TAREA: Tarea 849, ESTADO: Pendiente
# TAREA: Tarea 977, ESTADO: Pendiente
# TAREA: Tarea 651, ESTADO: Pendiente
# TAREA: Tarea 623, ESTADO: Pendiente
# TAREA: Tarea 850, ESTADO: Pendiente
# TAREA: Tarea 851, ESTADO: Pendiente
# TAREA: Tarea 978, ESTADO: Pendiente
# TAREA: Tarea 979, ESTADO: Pendiente
# TAREA: Tarea 721, ESTADO: Pendiente
# TAREA: Tarea 852, ESTADO: Pendiente
# TAREA: Tarea 980, ESTADO: Pendiente
# TAREA: Tarea 853, ESTADO: Pendiente
# TAREA: Tarea 981, ESTADO: Pendiente
# TAREA: Tarea 670, ESTADO: Pendiente
# TAREA: Tarea 727, ESTADO: Pendiente
# TAREA: Tarea 854, ESTADO: Pendiente
# TAREA: Tarea 982, ESTADO: Pendiente
# TAREA: Tarea 855, ESTADO: Pendiente
# TAREA: Tarea 638, ESTADO: Pendiente
# TAREA: Tarea 983, ESTADO: Pendiente
# TAREA: Tarea 775, ESTADO: Pendiente
# TAREA: Tarea 856, ESTADO: Pendiente
# TAREA: Tarea 984, ESTADO: Pendiente
# TAREA: Tarea 748, ESTADO: Pendiente
# TAREA: Tarea 857, ESTADO: Pendiente
# TAREA: Tarea 985, ESTADO: Pendiente
# TAREA: Tarea 858, ESTADO: Pendiente
# TAREA: Tarea 986, ESTADO: Pendiente
# TAREA: Tarea 859, ESTADO: Pendiente
# TAREA: Tarea 665, ESTADO: Pendiente
# TAREA: Tarea 987, ESTADO: Pendiente
# TAREA: Tarea 860, ESTADO: Pendiente
# TAREA: Tarea 632, ESTADO: Pendiente
# TAREA: Tarea 988, ESTADO: Pendiente
# TAREA: Tarea 861, ESTADO: Pendiente
# TAREA: Tarea 989, ESTADO: Pendiente
# TAREA: Tarea 862, ESTADO: Pendiente
# TAREA: Tarea 990, ESTADO: Pendiente
# TAREA: Tarea 863, ESTADO: Pendiente
# TAREA: Tarea 639, ESTADO: Pendiente
# TAREA: Tarea 991, ESTADO: Pendiente
# TAREA: Tarea 864, ESTADO: Pendiente
# TAREA: Tarea 992, ESTADO: Pendiente
# TAREA: Tarea 865, ESTADO: Pendiente
# TAREA: Tarea 993, ESTADO: Pendiente
# TAREA: Tarea 661, ESTADO: Pendiente
# TAREA: Tarea 746, ESTADO: Pendiente
# TAREA: Tarea 866, ESTADO: Pendiente
# TAREA: Tarea 867, ESTADO: Pendiente
# TAREA: Tarea 994, ESTADO: Pendiente
# TAREA: Tarea 995, ESTADO: Pendiente
# TAREA: Tarea 629, ESTADO: Pendiente
# TAREA: Tarea 868, ESTADO: Pendiente
# TAREA: Tarea 658, ESTADO: Pendiente
# TAREA: Tarea 996, ESTADO: Pendiente
# TAREA: Tarea 869, ESTADO: Pendiente
# TAREA: Tarea 997, ESTADO: Pendiente
# TAREA: Tarea 870, ESTADO: Pendiente
# TAREA: Tarea 998, ESTADO: Pendiente
# TAREA: Tarea 871, ESTADO: Pendiente
# TAREA: Tarea 635, ESTADO: Pendiente
# TAREA: Tarea 659, ESTADO: Pendiente
# TAREA: Tarea 714, ESTADO: Pendiente
# TAREA: Tarea 872, ESTADO: Pendiente
# TAREA: Tarea 999, ESTADO: Pendiente
# TAREA: Tarea 1000, ESTADO: Pendiente
# TAREA: Tarea 873, ESTADO: Pendiente
# TAREA: Tarea 646, ESTADO: Pendiente
# TAREA: Tarea 726, ESTADO: Pendiente
# TAREA: Tarea 874, ESTADO: Pendiente
# TAREA: Tarea 730, ESTADO: Pendiente
# TAREA: Tarea 875, ESTADO: Pendiente
# TAREA: Tarea 876, ESTADO: Pendiente
# TAREA: Tarea 666, ESTADO: Pendiente
# TAREA: Tarea 724, ESTADO: Pendiente
# TAREA: Tarea 750, ESTADO: Pendiente
# TAREA: Tarea 877, ESTADO: Pendiente
# TAREA: Tarea 878, ESTADO: Pendiente
# TAREA: Tarea 749, ESTADO: Pendiente
# TAREA: Tarea 879, ESTADO: Pendiente
# TAREA: Tarea 625, ESTADO: Pendiente
# TAREA: Tarea 644, ESTADO: Pendiente
# TAREA: Tarea 880, ESTADO: Pendiente
# TAREA: Tarea 744, ESTADO: Pendiente
# TAREA: Tarea 611, ESTADO: Pendiente
# TAREA: Tarea 881, ESTADO: Pendiente
# TAREA: Tarea 882, ESTADO: Pendiente
# TAREA: Tarea 883, ESTADO: Pendiente
# TAREA: Tarea 884, ESTADO: Pendiente
# TAREA: Tarea 885, ESTADO: Pendiente
# TAREA: Tarea 736, ESTADO: Pendiente
# TAREA: Tarea 616, ESTADO: Pendiente
# TAREA: Tarea 886, ESTADO: Pendiente
# TAREA: Tarea 720, ESTADO: Pendiente
# TAREA: Tarea 887, ESTADO: Pendiente
# TAREA: Tarea 617, ESTADO: Pendiente
# TAREA: Tarea 888, ESTADO: Pendiente
# TAREA: Tarea 745, ESTADO: Pendiente
# TAREA: Tarea 889, ESTADO: Pendiente
# TAREA: Tarea 637, ESTADO: Pendiente
# TAREA: Tarea 890, ESTADO: Pendiente
# TAREA: Tarea 891, ESTADO: Pendiente
# TAREA: Tarea 892, ESTADO: Pendiente
# TAREA: Tarea 893, ESTADO: Pendiente
# TAREA: Tarea 894, ESTADO: Pendiente
# TAREA: Tarea 612, ESTADO: Pendiente
# TAREA: Tarea 895, ESTADO: Pendiente
# TAREA: Tarea 896, ESTADO: Pendiente
# TAREA: Tarea 652, ESTADO: Pendiente
# TAREA: Tarea 897, ESTADO: Pendiente
# TAREA: Tarea 728, ESTADO: Pendiente
# TAREA: Tarea 898, ESTADO: Pendiente
# TAREA: Tarea 899, ESTADO: Pendiente
# TAREA: Tarea 900, ESTADO: Pendiente
# TAREA: Tarea 647, ESTADO: Pendiente
# TAREA: Tarea 901, ESTADO: Pendiente
# TAREA: Tarea 902, ESTADO: Pendiente
# TAREA: Tarea 903, ESTADO: Pendiente
# TAREA: Tarea 904, ESTADO: Pendiente
# TAREA: Tarea 668, ESTADO: Pendiente
# TAREA: Tarea 905, ESTADO: Pendiente
# TAREA: Tarea 906, ESTADO: Pendiente
# TAREA: Tarea 618, ESTADO: Pendiente
# TAREA: Tarea 715, ESTADO: Pendiente
# TAREA: Tarea 907, ESTADO: Pendiente
# TAREA: Tarea 630, ESTADO: Pendiente
# TAREA: Tarea 908, ESTADO: Pendiente
# TAREA: Tarea 909, ESTADO: Pendiente
# TAREA: Tarea 910, ESTADO: Pendiente
# TAREA: Tarea 624, ESTADO: Pendiente
# TAREA: Tarea 911, ESTADO: Pendiente
# TAREA: Tarea 747, ESTADO: Pendiente
# TAREA: Tarea 912, ESTADO: Pendiente
# TAREA: Tarea 913, ESTADO: Pendiente
# TAREA: Tarea 914, ESTADO: Pendiente
# TAREA: Tarea 915, ESTADO: Pendiente
# TAREA: Tarea 916, ESTADO: Pendiente
# TAREA: Tarea 627, ESTADO: Pendiente
# TAREA: Tarea 917, ESTADO: Pendiente
# TAREA: Tarea 918, ESTADO: Pendiente
# TAREA: Tarea 643, ESTADO: Pendiente
# TAREA: Tarea 634, ESTADO: Pendiente
# TAREA: Tarea 919, ESTADO: Pendiente
# TAREA: Tarea 607, ESTADO: Pendiente
# TAREA: Tarea 606, ESTADO: Pendiente
# TAREA: Tarea 608, ESTADO: Pendiente
# TAREA: Tarea 507, ESTADO: Pendiente
# TAREA: Tarea 605, ESTADO: Pendiente
# TAREA: Tarea 602, ESTADO: Pendiente
# TAREA: Tarea 769, ESTADO: Pendiente
# TAREA: Tarea 786, ESTADO: Pendiente
# TAREA: Tarea 601, ESTADO: Pendiente
# TAREA: Tarea 765, ESTADO: Pendiente
# TAREA: Tarea 603, ESTADO: Pendiente
# TAREA: Tarea 600, ESTADO: Pendiente
# TAREA: Tarea 597, ESTADO: Pendiente
# TAREA: Tarea 762, ESTADO: Pendiente
# TAREA: Tarea 793, ESTADO: Pendiente
# TAREA: Tarea 772, ESTADO: Pendiente
# TAREA: Tarea 791, ESTADO: Pendiente
# TAREA: Tarea 502, ESTADO: Pendiente
# TAREA: Tarea 596, ESTADO: Pendiente
# TAREA: Tarea 595, ESTADO: Pendiente
# TAREA: Tarea 792, ESTADO: Pendiente
# TAREA: Tarea 591, ESTADO: Pendiente
# TAREA: Tarea 783, ESTADO: Pendiente
# TAREA: Tarea 504, ESTADO: Pendiente
# TAREA: Tarea 598, ESTADO: Pendiente
# TAREA: Tarea 764, ESTADO: Pendiente
# TAREA: Tarea 593, ESTADO: Pendiente
# TAREA: Tarea 771, ESTADO: Pendiente
# TAREA: Tarea 789, ESTADO: Pendiente
# TAREA: Tarea 592, ESTADO: Pendiente
# TAREA: Tarea 770, ESTADO: Pendiente
# TAREA: Tarea 784, ESTADO: Pendiente
# TAREA: Tarea 599, ESTADO: Pendiente
# TAREA: Tarea 594, ESTADO: Pendiente
# TAREA: Tarea 604, ESTADO: Pendiente
# TAREA: Tarea 590, ESTADO: Pendiente
# TAREA: Tarea 589, ESTADO: Pendiente
# TAREA: Tarea 588, ESTADO: Pendiente
# TAREA: Tarea 751, ESTADO: Pendiente
# TAREA: Tarea 584, ESTADO: Pendiente
# TAREA: Tarea 583, ESTADO: Pendiente
# TAREA: Tarea 587, ESTADO: Pendiente
# TAREA: Tarea 505, ESTADO: Pendiente
# TAREA: Tarea 578, ESTADO: Pendiente
# TAREA: Tarea 585, ESTADO: Pendiente
# TAREA: Tarea 752, ESTADO: Pendiente
# TAREA: Tarea 586, ESTADO: Pendiente
# TAREA: Tarea 582, ESTADO: Pendiente
# TAREA: Tarea 574, ESTADO: Pendiente
# TAREA: Tarea 755, ESTADO: Pendiente
# TAREA: Tarea 573, ESTADO: Pendiente
# TAREA: Tarea 785, ESTADO: Pendiente
# TAREA: Tarea 581, ESTADO: Pendiente
# TAREA: Tarea 711, ESTADO: Pendiente
# TAREA: Tarea 571, ESTADO: Pendiente
# TAREA: Tarea 579, ESTADO: Pendiente
# TAREA: Tarea 580, ESTADO: Pendiente
# TAREA: Tarea 712, ESTADO: Pendiente
# TAREA: Tarea 568, ESTADO: Pendiente
# TAREA: Tarea 773, ESTADO: Pendiente
# TAREA: Tarea 577, ESTADO: Pendiente
# TAREA: Tarea 566, ESTADO: Pendiente
# TAREA: Tarea 719, ESTADO: Pendiente
# TAREA: Tarea 790, ESTADO: Pendiente
# TAREA: Tarea 565, ESTADO: Pendiente
# TAREA: Tarea 575, ESTADO: Pendiente
# TAREA: Tarea 572, ESTADO: Pendiente
# TAREA: Tarea 576, ESTADO: Pendiente
# TAREA: Tarea 754, ESTADO: Pendiente
# TAREA: Tarea 788, ESTADO: Pendiente
# TAREA: Tarea 564, ESTADO: Pendiente
# TAREA: Tarea 570, ESTADO: Pendiente
# TAREA: Tarea 569, ESTADO: Pendiente
# TAREA: Tarea 757, ESTADO: Pendiente
# TAREA: Tarea 763, ESTADO: Pendiente
# TAREA: Tarea 561, ESTADO: Pendiente
# TAREA: Tarea 795, ESTADO: Pendiente
# TAREA: Tarea 778, ESTADO: Pendiente
# TAREA: Tarea 758, ESTADO: Pendiente
# TAREA: Tarea 567, ESTADO: Pendiente
# TAREA: Tarea 787, ESTADO: Pendiente
# TAREA: Tarea 546, ESTADO: Pendiente
# TAREA: Tarea 794, ESTADO: Pendiente
# TAREA: Tarea 563, ESTADO: Pendiente
# TAREA: Tarea 554, ESTADO: Pendiente
# TAREA: Tarea 562, ESTADO: Pendiente
# TAREA: Tarea 555, ESTADO: Pendiente
# TAREA: Tarea 781, ESTADO: Pendiente
# TAREA: Tarea 559, ESTADO: Pendiente
# TAREA: Tarea 552, ESTADO: Pendiente
# TAREA: Tarea 780, ESTADO: Pendiente
# TAREA: Tarea 548, ESTADO: Pendiente
# TAREA: Tarea 759, ESTADO: Pendiente
# TAREA: Tarea 558, ESTADO: Pendiente
# TAREA: Tarea 556, ESTADO: Pendiente
# TAREA: Tarea 553, ESTADO: Pendiente
# TAREA: Tarea 557, ESTADO: Pendiente
# TAREA: Tarea 547, ESTADO: Pendiente
# TAREA: Tarea 550, ESTADO: Pendiente
# TAREA: Tarea 779, ESTADO: Pendiente
# TAREA: Tarea 560, ESTADO: Pendiente
# TAREA: Tarea 731, ESTADO: Pendiente
# TAREA: Tarea 544, ESTADO: Pendiente
# TAREA: Tarea 551, ESTADO: Pendiente
# TAREA: Tarea 545, ESTADO: Pendiente
# TAREA: Tarea 732, ESTADO: Pendiente
# TAREA: Tarea 549, ESTADO: Pendiente
# TAREA: Tarea 501, ESTADO: Pendiente
# TAREA: Tarea 539, ESTADO: Pendiente
# TAREA: Tarea 740, ESTADO: Pendiente
# TAREA: Tarea 538, ESTADO: Pendiente
# TAREA: Tarea 534, ESTADO: Pendiente
# TAREA: Tarea 741, ESTADO: Pendiente
# TAREA: Tarea 535, ESTADO: Pendiente
# TAREA: Tarea 761, ESTADO: Pendiente
# TAREA: Tarea 537, ESTADO: Pendiente
# TAREA: Tarea 543, ESTADO: Pendiente
# TAREA: Tarea 541, ESTADO: Pendiente
# TAREA: Tarea 739, ESTADO: Pendiente
# TAREA: Tarea 756, ESTADO: Pendiente
# TAREA: Tarea 533, ESTADO: Pendiente
# TAREA: Tarea 710, ESTADO: Pendiente
# TAREA: Tarea 753, ESTADO: Pendiente
# TAREA: Tarea 529, ESTADO: Pendiente
# TAREA: Tarea 503, ESTADO: Pendiente
# TAREA: Tarea 532, ESTADO: Pendiente
# TAREA: Tarea 734, ESTADO: Pendiente
# TAREA: Tarea 709, ESTADO: Pendiente
# TAREA: Tarea 531, ESTADO: Pendiente
# TAREA: Tarea 708, ESTADO: Pendiente
# TAREA: Tarea 707, ESTADO: Pendiente
# TAREA: Tarea 706, ESTADO: Pendiente
# TAREA: Tarea 540, ESTADO: Pendiente
# TAREA: Tarea 705, ESTADO: Pendiente
# TAREA: Tarea 738, ESTADO: Pendiente
# TAREA: Tarea 542, ESTADO: Pendiente
# TAREA: Tarea 704, ESTADO: Pendiente
# TAREA: Tarea 703, ESTADO: Pendiente
# TAREA: Tarea 702, ESTADO: Pendiente
# TAREA: Tarea 536, ESTADO: Pendiente
# TAREA: Tarea 701, ESTADO: Pendiente
# TAREA: Tarea 700, ESTADO: Pendiente
# TAREA: Tarea 699, ESTADO: Pendiente
# TAREA: Tarea 530, ESTADO: Pendiente
# TAREA: Tarea 698, ESTADO: Pendiente
# TAREA: Tarea 697, ESTADO: Pendiente
# TAREA: Tarea 527, ESTADO: Pendiente
# TAREA: Tarea 696, ESTADO: Pendiente
# TAREA: Tarea 760, ESTADO: Pendiente
# TAREA: Tarea 526, ESTADO: Pendiente
# TAREA: Tarea 695, ESTADO: Pendiente
# TAREA: Tarea 525, ESTADO: Pendiente
# TAREA: Tarea 768, ESTADO: Pendiente
# TAREA: Tarea 694, ESTADO: Pendiente
# TAREA: Tarea 524, ESTADO: Pendiente
# TAREA: Tarea 511, ESTADO: Pendiente
# TAREA: Tarea 693, ESTADO: Pendiente
# TAREA: Tarea 735, ESTADO: Pendiente
# TAREA: Tarea 523, ESTADO: Pendiente
# TAREA: Tarea 692, ESTADO: Pendiente
# TAREA: Tarea 519, ESTADO: Pendiente
# TAREA: Tarea 522, ESTADO: Pendiente
# TAREA: Tarea 677, ESTADO: Pendiente
# TAREA: Tarea 521, ESTADO: Pendiente
# TAREA: Tarea 676, ESTADO: Pendiente
# TAREA: Tarea 520, ESTADO: Pendiente
# TAREA: Tarea 678, ESTADO: Pendiente
# TAREA: Tarea 767, ESTADO: Pendiente
# TAREA: Tarea 675, ESTADO: Pendiente
# TAREA: Tarea 518, ESTADO: Pendiente
# TAREA: Tarea 679, ESTADO: Pendiente
# TAREA: Tarea 690, ESTADO: Pendiente
# TAREA: Tarea 766, ESTADO: Pendiente
# TAREA: Tarea 691, ESTADO: Pendiente
# TAREA: Tarea 515, ESTADO: Pendiente
# TAREA: Tarea 516, ESTADO: Pendiente
# TAREA: Tarea 689, ESTADO: Pendiente
# TAREA: Tarea 528, ESTADO: Pendiente
# TAREA: Tarea 674, ESTADO: Pendiente
# TAREA: Tarea 514, ESTADO: Pendiente
# TAREA: Tarea 673, ESTADO: Pendiente
# TAREA: Tarea 733, ESTADO: Pendiente
# TAREA: Tarea 517, ESTADO: Pendiente
# TAREA: Tarea 513, ESTADO: Pendiente
# TAREA: Tarea 512, ESTADO: Pendiente
# TAREA: Tarea 685, ESTADO: Pendiente
# TAREA: Tarea 672, ESTADO: Pendiente
# TAREA: Tarea 510, ESTADO: Pendiente
# TAREA: Tarea 686, ESTADO: Pendiente
# TAREA: Tarea 509, ESTADO: Pendiente
# TAREA: Tarea 687, ESTADO: Pendiente
# TAREA: Tarea 688, ESTADO: Pendiente
# TAREA: Tarea 508, ESTADO: Pendiente
# TAREA: Tarea 684, ESTADO: Pendiente
# TAREA: Tarea 682, ESTADO: Pendiente
# TAREA: Tarea 782, ESTADO: Pendiente
# TAREA: Tarea 683, ESTADO: Pendiente
# TAREA: Tarea 681, ESTADO: Pendiente
# TAREA: Tarea 717, ESTADO: Pendiente
# TAREA: Tarea 671, ESTADO: Pendiente
# TAREA: Tarea 506, ESTADO: Pendiente
# TAREA: Tarea 641, ESTADO: Pendiente
# TAREA: Tarea 680, ESTADO: Pendiente
# TAREA: Tarea 737, ESTADO: Pendiente
# TAREA: Tarea 718, ESTADO: Pendiente
# TAREA: Tarea 350, ESTADO: Pendiente
# TAREA: Tarea 153, ESTADO: Pendiente
# TAREA: Tarea 122, ESTADO: Pendiente
# TAREA: Tarea 376, ESTADO: Pendiente
# TAREA: Tarea 93, ESTADO: Pendiente
# TAREA: Tarea 120, ESTADO: Pendiente
# TAREA: Tarea 142, ESTADO: Pendiente
# TAREA: Tarea 339, ESTADO: Pendiente
# TAREA: Tarea 125, ESTADO: Pendiente
# TAREA: Tarea 92, ESTADO: Pendiente
# TAREA: Tarea 200, ESTADO: Pendiente
# TAREA: Tarea 342, ESTADO: Pendiente
# TAREA: Tarea 414, ESTADO: Pendiente
# TAREA: Tarea 123, ESTADO: Pendiente
# TAREA: Tarea 340, ESTADO: Pendiente
# TAREA: Tarea 102, ESTADO: Pendiente
# TAREA: Tarea 341, ESTADO: Pendiente
# TAREA: Tarea 95, ESTADO: Pendiente
# TAREA: Tarea 343, ESTADO: Pendiente
# TAREA: Tarea 98, ESTADO: Pendiente
# TAREA: Tarea 127, ESTADO: Pendiente
# TAREA: Tarea 97, ESTADO: Pendiente
# TAREA: Tarea 357, ESTADO: Pendiente
# TAREA: Tarea 126, ESTADO: Pendiente
# TAREA: Tarea 345, ESTADO: Pendiente
# TAREA: Tarea 99, ESTADO: Pendiente
# TAREA: Tarea 130, ESTADO: Pendiente
# TAREA: Tarea 167, ESTADO: Pendiente
# TAREA: Tarea 346, ESTADO: Pendiente
# TAREA: Tarea 131, ESTADO: Pendiente
# TAREA: Tarea 411, ESTADO: Pendiente
# TAREA: Tarea 128, ESTADO: Pendiente
# TAREA: Tarea 380, ESTADO: Pendiente
# TAREA: Tarea 162, ESTADO: Pendiente
# TAREA: Tarea 94, ESTADO: Pendiente
# TAREA: Tarea 358, ESTADO: Pendiente
# TAREA: Tarea 196, ESTADO: Pendiente
# TAREA: Tarea 82, ESTADO: Pendiente
# TAREA: Tarea 129, ESTADO: Pendiente
# TAREA: Tarea 344, ESTADO: Pendiente
# TAREA: Tarea 124, ESTADO: Pendiente
# TAREA: Tarea 143, ESTADO: Pendiente
# TAREA: Tarea 101, ESTADO: Pendiente
# TAREA: Tarea 420, ESTADO: Pendiente
# TAREA: Tarea 83, ESTADO: Pendiente
# TAREA: Tarea 132, ESTADO: Pendiente
# TAREA: Tarea 134, ESTADO: Pendiente
# TAREA: Tarea 133, ESTADO: Pendiente
# TAREA: Tarea 347, ESTADO: Pendiente
# TAREA: Tarea 349, ESTADO: Pendiente
# TAREA: Tarea 135, ESTADO: Pendiente
# TAREA: Tarea 136, ESTADO: Pendiente
# TAREA: Tarea 348, ESTADO: Pendiente
# TAREA: Tarea 104, ESTADO: Pendiente
# TAREA: Tarea 75, ESTADO: Pendiente
# TAREA: Tarea 175, ESTADO: Pendiente
# TAREA: Tarea 158, ESTADO: Pendiente
# TAREA: Tarea 145, ESTADO: Pendiente
# TAREA: Tarea 154, ESTADO: Pendiente
# TAREA: Tarea 352, ESTADO: Pendiente
# TAREA: Tarea 144, ESTADO: Pendiente
# TAREA: Tarea 100, ESTADO: Pendiente
# TAREA: Tarea 203, ESTADO: Pendiente
# TAREA: Tarea 359, ESTADO: Pendiente
# TAREA: Tarea 67, ESTADO: Pendiente
# TAREA: Tarea 379, ESTADO: Pendiente
# TAREA: Tarea 190, ESTADO: Pendiente
# TAREA: Tarea 361, ESTADO: Pendiente
# TAREA: Tarea 396, ESTADO: Pendiente
# TAREA: Tarea 493, ESTADO: Pendiente
# TAREA: Tarea 138, ESTADO: Pendiente
# TAREA: Tarea 405, ESTADO: Pendiente
# TAREA: Tarea 494, ESTADO: Pendiente
# TAREA: Tarea 141, ESTADO: Pendiente
# TAREA: Tarea 458, ESTADO: Pendiente
# TAREA: Tarea 139, ESTADO: Pendiente
# TAREA: Tarea 146, ESTADO: Pendiente
# TAREA: Tarea 417, ESTADO: Pendiente
# TAREA: Tarea 147, ESTADO: Pendiente
# TAREA: Tarea 453, ESTADO: Pendiente
# TAREA: Tarea 137, ESTADO: Pendiente
# TAREA: Tarea 369, ESTADO: Pendiente
# TAREA: Tarea 360, ESTADO: Pendiente
# TAREA: Tarea 140, ESTADO: Pendiente
# TAREA: Tarea 489, ESTADO: Pendiente
# TAREA: Tarea 487, ESTADO: Pendiente
# TAREA: Tarea 495, ESTADO: Pendiente
# TAREA: Tarea 353, ESTADO: Pendiente
# TAREA: Tarea 492, ESTADO: Pendiente
# TAREA: Tarea 483, ESTADO: Pendiente
# TAREA: Tarea 109, ESTADO: Pendiente
# TAREA: Tarea 149, ESTADO: Pendiente
# TAREA: Tarea 354, ESTADO: Pendiente
# TAREA: Tarea 88, ESTADO: Pendiente
# TAREA: Tarea 356, ESTADO: Pendiente
# TAREA: Tarea 148, ESTADO: Pendiente
# TAREA: Tarea 490, ESTADO: Pendiente
# TAREA: Tarea 355, ESTADO: Pendiente
# TAREA: Tarea 491, ESTADO: Pendiente
# TAREA: Tarea 486, ESTADO: Pendiente
# TAREA: Tarea 482, ESTADO: Pendiente
# TAREA: Tarea 150, ESTADO: Pendiente
# TAREA: Tarea 362, ESTADO: Pendiente
# TAREA: Tarea 367, ESTADO: Pendiente
# TAREA: Tarea 106, ESTADO: Pendiente
# TAREA: Tarea 152, ESTADO: Pendiente
# TAREA: Tarea 481, ESTADO: Pendiente
# TAREA: Tarea 151, ESTADO: Pendiente
# TAREA: Tarea 364, ESTADO: Pendiente
# TAREA: Tarea 365, ESTADO: Pendiente
# TAREA: Tarea 156, ESTADO: Pendiente
# TAREA: Tarea 363, ESTADO: Pendiente
# TAREA: Tarea 497, ESTADO: Pendiente
# TAREA: Tarea 366, ESTADO: Pendiente
# TAREA: Tarea 103, ESTADO: Pendiente
# TAREA: Tarea 368, ESTADO: Pendiente
# TAREA: Tarea 157, ESTADO: Pendiente
# TAREA: Tarea 351, ESTADO: Pendiente
# TAREA: Tarea 373, ESTADO: Pendiente
# TAREA: Tarea 480, ESTADO: Pendiente
# TAREA: Tarea 418, ESTADO: Pendiente
# TAREA: Tarea 474, ESTADO: Pendiente
# TAREA: Tarea 108, ESTADO: Pendiente
# TAREA: Tarea 370, ESTADO: Pendiente
# TAREA: Tarea 477, ESTADO: Pendiente
# TAREA: Tarea 86, ESTADO: Pendiente
# TAREA: Tarea 433, ESTADO: Pendiente
# TAREA: Tarea 84, ESTADO: Pendiente
# TAREA: Tarea 371, ESTADO: Pendiente
# TAREA: Tarea 476, ESTADO: Pendiente
# TAREA: Tarea 484, ESTADO: Pendiente
# TAREA: Tarea 72, ESTADO: Pendiente
# TAREA: Tarea 456, ESTADO: Pendiente
# TAREA: Tarea 372, ESTADO: Pendiente
# TAREA: Tarea 90, ESTADO: Pendiente
# TAREA: Tarea 191, ESTADO: Pendiente
# TAREA: Tarea 192, ESTADO: Pendiente
# TAREA: Tarea 416, ESTADO: Pendiente
# TAREA: Tarea 485, ESTADO: Pendiente
# TAREA: Tarea 478, ESTADO: Pendiente
# TAREA: Tarea 112, ESTADO: Pendiente
# TAREA: Tarea 374, ESTADO: Pendiente
# TAREA: Tarea 471, ESTADO: Pendiente
# TAREA: Tarea 469, ESTADO: Pendiente
# TAREA: Tarea 377, ESTADO: Pendiente
# TAREA: Tarea 159, ESTADO: Pendiente
# TAREA: Tarea 419, ESTADO: Pendiente
# TAREA: Tarea 375, ESTADO: Pendiente
# TAREA: Tarea 118, ESTADO: Pendiente
# TAREA: Tarea 188, ESTADO: Pendiente
# TAREA: Tarea 421, ESTADO: Pendiente
# TAREA: Tarea 470, ESTADO: Pendiente
# TAREA: Tarea 198, ESTADO: Pendiente
# TAREA: Tarea 475, ESTADO: Pendiente
# TAREA: Tarea 472, ESTADO: Pendiente
# TAREA: Tarea 199, ESTADO: Pendiente
# TAREA: Tarea 473, ESTADO: Pendiente
# TAREA: Tarea 488, ESTADO: Pendiente
# TAREA: Tarea 110, ESTADO: Pendiente
# TAREA: Tarea 160, ESTADO: Pendiente
# TAREA: Tarea 89, ESTADO: Pendiente
# TAREA: Tarea 479, ESTADO: Pendiente
# TAREA: Tarea 161, ESTADO: Pendiente
# TAREA: Tarea 468, ESTADO: Pendiente
# TAREA: Tarea 498, ESTADO: Pendiente
# TAREA: Tarea 35, ESTADO: Pendiente
# TAREA: Tarea 73, ESTADO: Pendiente
# TAREA: Tarea 432, ESTADO: Pendiente
# TAREA: Tarea 37, ESTADO: Pendiente
# TAREA: Tarea 111, ESTADO: Pendiente
# TAREA: Tarea 201, ESTADO: Pendiente
# TAREA: Tarea 114, ESTADO: Pendiente
# TAREA: Tarea 163, ESTADO: Pendiente
# TAREA: Tarea 113, ESTADO: Pendiente
# TAREA: Tarea 466, ESTADO: Pendiente
# TAREA: Tarea 410, ESTADO: Pendiente
# TAREA: Tarea 465, ESTADO: Pendiente
# TAREA: Tarea 467, ESTADO: Pendiente
# TAREA: Tarea 1, ESTADO: Pendiente
# TAREA: Tarea 115, ESTADO: Pendiente
# TAREA: Tarea 382, ESTADO: Pendiente
# TAREA: Tarea 116, ESTADO: Pendiente
# TAREA: Tarea 378, ESTADO: Pendiente
# TAREA: Tarea 155, ESTADO: Pendiente
# TAREA: Tarea 168, ESTADO: Pendiente
# TAREA: Tarea 53, ESTADO: Pendiente
# TAREA: Tarea 177, ESTADO: Pendiente
# TAREA: Tarea 496, ESTADO: Pendiente
# TAREA: Tarea 76, ESTADO: Pendiente
# TAREA: Tarea 59, ESTADO: Pendiente
# TAREA: Tarea 202, ESTADO: Pendiente
# TAREA: Tarea 117, ESTADO: Pendiente
# TAREA: Tarea 55, ESTADO: Pendiente
# TAREA: Tarea 408, ESTADO: Pendiente
# TAREA: Tarea 119, ESTADO: Pendiente
# TAREA: Tarea 457, ESTADO: Pendiente
# TAREA: Tarea 454, ESTADO: Pendiente
# TAREA: Tarea 58, ESTADO: Pendiente
# TAREA: Tarea 381, ESTADO: Pendiente
# TAREA: Tarea 462, ESTADO: Pendiente
# TAREA: Tarea 164, ESTADO: Pendiente
# TAREA: Tarea 464, ESTADO: Pendiente
# TAREA: Tarea 455, ESTADO: Pendiente
# TAREA: Tarea 461, ESTADO: Pendiente
# TAREA: Tarea 39, ESTADO: Pendiente
# TAREA: Tarea 440, ESTADO: Pendiente
# TAREA: Tarea 41, ESTADO: Pendiente
# TAREA: Tarea 460, ESTADO: Pendiente
# TAREA: Tarea 459, ESTADO: Pendiente
# TAREA: Tarea 57, ESTADO: Pendiente
# TAREA: Tarea 165, ESTADO: Pendiente
# TAREA: Tarea 38, ESTADO: Pendiente
# TAREA: Tarea 383, ESTADO: Pendiente
# TAREA: Tarea 441, ESTADO: Pendiente
# TAREA: Tarea 384, ESTADO: Pendiente
# TAREA: Tarea 463, ESTADO: Pendiente
# TAREA: Tarea 87, ESTADO: Pendiente
# TAREA: Tarea 40, ESTADO: Pendiente
# TAREA: Tarea 197, ESTADO: Pendiente
# TAREA: Tarea 60, ESTADO: Pendiente
# TAREA: Tarea 166, ESTADO: Pendiente
# TAREA: Tarea 385, ESTADO: Pendiente
# TAREA: Tarea 36, ESTADO: Pendiente
# TAREA: Tarea 61, ESTADO: Pendiente
# TAREA: Tarea 451, ESTADO: Pendiente
# TAREA: Tarea 45, ESTADO: Pendiente
# TAREA: Tarea 169, ESTADO: Pendiente
# TAREA: Tarea 387, ESTADO: Pendiente
# TAREA: Tarea 448, ESTADO: Pendiente
# TAREA: Tarea 450, ESTADO: Pendiente
# TAREA: Tarea 78, ESTADO: Pendiente
# TAREA: Tarea 386, ESTADO: Pendiente
# TAREA: Tarea 447, ESTADO: Pendiente
# TAREA: Tarea 449, ESTADO: Pendiente
# TAREA: Tarea 77, ESTADO: Pendiente
# TAREA: Tarea 170, ESTADO: Pendiente
# TAREA: Tarea 397, ESTADO: Pendiente
# TAREA: Tarea 398, ESTADO: Pendiente
# TAREA: Tarea 51, ESTADO: Pendiente
# TAREA: Tarea 173, ESTADO: Pendiente
# TAREA: Tarea 105, ESTADO: Pendiente
# TAREA: Tarea 388, ESTADO: Pendiente
# TAREA: Tarea 446, ESTADO: Pendiente
# TAREA: Tarea 171, ESTADO: Pendiente
# TAREA: Tarea 452, ESTADO: Pendiente
# TAREA: Tarea 445, ESTADO: Pendiente
# TAREA: Tarea 390, ESTADO: Pendiente
# TAREA: Tarea 62, ESTADO: Pendiente
# TAREA: Tarea 174, ESTADO: Pendiente
# TAREA: Tarea 444, ESTADO: Pendiente
# TAREA: Tarea 43, ESTADO: Pendiente
# TAREA: Tarea 63, ESTADO: Pendiente
# TAREA: Tarea 391, ESTADO: Pendiente
# TAREA: Tarea 66, ESTADO: Pendiente
# TAREA: Tarea 443, ESTADO: Pendiente
# TAREA: Tarea 64, ESTADO: Pendiente
# TAREA: Tarea 172, ESTADO: Pendiente
# TAREA: Tarea 389, ESTADO: Pendiente
# TAREA: Tarea 393, ESTADO: Pendiente
# TAREA: Tarea 439, ESTADO: Pendiente
# TAREA: Tarea 195, ESTADO: Pendiente
# TAREA: Tarea 49, ESTADO: Pendiente
# TAREA: Tarea 176, ESTADO: Pendiente
# TAREA: Tarea 50, ESTADO: Pendiente
# TAREA: Tarea 179, ESTADO: Pendiente
# TAREA: Tarea 187, ESTADO: Pendiente
# TAREA: Tarea 392, ESTADO: Pendiente
# TAREA: Tarea 65, ESTADO: Pendiente
# TAREA: Tarea 180, ESTADO: Pendiente
# TAREA: Tarea 499, ESTADO: Pendiente
# TAREA: Tarea 68, ESTADO: Pendiente
# TAREA: Tarea 183, ESTADO: Pendiente
# TAREA: Tarea 437, ESTADO: Pendiente
# TAREA: Tarea 394, ESTADO: Pendiente
# TAREA: Tarea 404, ESTADO: Pendiente
# TAREA: Tarea 71, ESTADO: Pendiente
# TAREA: Tarea 430, ESTADO: Pendiente
# TAREA: Tarea 395, ESTADO: Pendiente
# TAREA: Tarea 435, ESTADO: Pendiente
# TAREA: Tarea 70, ESTADO: Pendiente
# TAREA: Tarea 48, ESTADO: Pendiente
# TAREA: Tarea 178, ESTADO: Pendiente
# TAREA: Tarea 189, ESTADO: Pendiente
# TAREA: Tarea 401, ESTADO: Pendiente
# TAREA: Tarea 442, ESTADO: Pendiente
# TAREA: Tarea 54, ESTADO: Pendiente
# TAREA: Tarea 436, ESTADO: Pendiente
# TAREA: Tarea 69, ESTADO: Pendiente
# TAREA: Tarea 438, ESTADO: Pendiente
# TAREA: Tarea 56, ESTADO: Pendiente
# TAREA: Tarea 431, ESTADO: Pendiente
# TAREA: Tarea 182, ESTADO: Pendiente
# TAREA: Tarea 193, ESTADO: Pendiente
# TAREA: Tarea 74, ESTADO: Pendiente
# TAREA: Tarea 121, ESTADO: Pendiente
# TAREA: Tarea 399, ESTADO: Pendiente
# TAREA: Tarea 426, ESTADO: Pendiente
# TAREA: Tarea 80, ESTADO: Pendiente
# TAREA: Tarea 181, ESTADO: Pendiente
# TAREA: Tarea 96, ESTADO: Pendiente
# TAREA: Tarea 400, ESTADO: Pendiente
# TAREA: Tarea 406, ESTADO: Pendiente
# TAREA: Tarea 434, ESTADO: Pendiente
# TAREA: Tarea 42, ESTADO: Pendiente
# TAREA: Tarea 194, ESTADO: Pendiente
# TAREA: Tarea 79, ESTADO: Pendiente
# TAREA: Tarea 425, ESTADO: Pendiente
# TAREA: Tarea 407, ESTADO: Pendiente
# TAREA: Tarea 429, ESTADO: Pendiente
# TAREA: Tarea 46, ESTADO: Pendiente
# TAREA: Tarea 184, ESTADO: Pendiente
# TAREA: Tarea 412, ESTADO: Pendiente
# TAREA: Tarea 427, ESTADO: Pendiente
# TAREA: Tarea 47, ESTADO: Pendiente
# TAREA: Tarea 44, ESTADO: Pendiente
# TAREA: Tarea 428, ESTADO: Pendiente
# TAREA: Tarea 409, ESTADO: Pendiente
# TAREA: Tarea 424, ESTADO: Pendiente
# TAREA: Tarea 85, ESTADO: Pendiente
# TAREA: Tarea 186, ESTADO: Pendiente
# TAREA: Tarea 402, ESTADO: Pendiente
# TAREA: Tarea 107, ESTADO: Pendiente
# TAREA: Tarea 81, ESTADO: Pendiente
# TAREA: Tarea 413, ESTADO: Pendiente
# TAREA: Tarea 91, ESTADO: Pendiente
# TAREA: Tarea 403, ESTADO: Pendiente
# TAREA: Tarea 423, ESTADO: Pendiente
# TAREA: Tarea 52, ESTADO: Pendiente
# TAREA: Tarea 185, ESTADO: Pendiente
# TAREA: Tarea 415, ESTADO: Pendiente
# TAREA: Tarea 422, ESTADO: Pendiente
# TAREA: Tarea 337, ESTADO: Pendiente
# TAREA: Tarea 13, ESTADO: Pendiente
# TAREA: Tarea 212, ESTADO: Pendiente
# TAREA: Tarea 28, ESTADO: Pendiente
# TAREA: Tarea 294, ESTADO: Pendiente
# TAREA: Tarea 334, ESTADO: Pendiente
# TAREA: Tarea 297, ESTADO: Pendiente
# TAREA: Tarea 211, ESTADO: Pendiente
# TAREA: Tarea 209, ESTADO: Pendiente
# TAREA: Tarea 336, ESTADO: Pendiente
# TAREA: Tarea 333, ESTADO: Pendiente
# TAREA: Tarea 213, ESTADO: Pendiente
# TAREA: Tarea 296, ESTADO: Pendiente
# TAREA: Tarea 205, ESTADO: Pendiente
# TAREA: Tarea 332, ESTADO: Pendiente
# TAREA: Tarea 338, ESTADO: Pendiente
# TAREA: Tarea 216, ESTADO: Pendiente
# TAREA: Tarea 215, ESTADO: Pendiente
# TAREA: Tarea 321, ESTADO: Pendiente
# TAREA: Tarea 204, ESTADO: Pendiente
# TAREA: Tarea 335, ESTADO: Pendiente
# TAREA: Tarea 331, ESTADO: Pendiente
# TAREA: Tarea 217, ESTADO: Pendiente
# TAREA: Tarea 328, ESTADO: Pendiente
# TAREA: Tarea 327, ESTADO: Pendiente
# TAREA: Tarea 214, ESTADO: Pendiente
# TAREA: Tarea 326, ESTADO: Pendiente
# TAREA: Tarea 329, ESTADO: Pendiente
# TAREA: Tarea 25, ESTADO: Pendiente
# TAREA: Tarea 207, ESTADO: Pendiente
# TAREA: Tarea 220, ESTADO: Pendiente
# TAREA: Tarea 316, ESTADO: Pendiente
# TAREA: Tarea 325, ESTADO: Pendiente
# TAREA: Tarea 295, ESTADO: Pendiente
# TAREA: Tarea 324, ESTADO: Pendiente
# TAREA: Tarea 322, ESTADO: Pendiente
# TAREA: Tarea 219, ESTADO: Pendiente
# TAREA: Tarea 319, ESTADO: Pendiente
# TAREA: Tarea 323, ESTADO: Pendiente
# TAREA: Tarea 318, ESTADO: Pendiente
# TAREA: Tarea 218, ESTADO: Pendiente
# TAREA: Tarea 293, ESTADO: Pendiente
# TAREA: Tarea 320, ESTADO: Pendiente
# TAREA: Tarea 206, ESTADO: Pendiente
# TAREA: Tarea 30, ESTADO: Pendiente
# TAREA: Tarea 315, ESTADO: Pendiente
# TAREA: Tarea 33, ESTADO: Pendiente
# TAREA: Tarea 221, ESTADO: Pendiente
# TAREA: Tarea 317, ESTADO: Pendiente
# TAREA: Tarea 222, ESTADO: Pendiente
# TAREA: Tarea 314, ESTADO: Pendiente
# TAREA: Tarea 313, ESTADO: Pendiente
# TAREA: Tarea 34, ESTADO: Pendiente
# TAREA: Tarea 312, ESTADO: Pendiente
# TAREA: Tarea 223, ESTADO: Pendiente
# TAREA: Tarea 226, ESTADO: Pendiente
# TAREA: Tarea 311, ESTADO: Pendiente
# TAREA: Tarea 20, ESTADO: Pendiente
# TAREA: Tarea 225, ESTADO: Pendiente
# TAREA: Tarea 309, ESTADO: Pendiente
# TAREA: Tarea 227, ESTADO: Pendiente
# TAREA: Tarea 248, ESTADO: Pendiente
# TAREA: Tarea 308, ESTADO: Pendiente
# TAREA: Tarea 233, ESTADO: Pendiente
# TAREA: Tarea 228, ESTADO: Pendiente
# TAREA: Tarea 310, ESTADO: Pendiente
# TAREA: Tarea 224, ESTADO: Pendiente
# TAREA: Tarea 11, ESTADO: Pendiente
# TAREA: Tarea 231, ESTADO: Pendiente
# TAREA: Tarea 232, ESTADO: Pendiente
# TAREA: Tarea 229, ESTADO: Pendiente
# TAREA: Tarea 307, ESTADO: Pendiente
# TAREA: Tarea 230, ESTADO: Pendiente
# TAREA: Tarea 306, ESTADO: Pendiente
# TAREA: Tarea 5, ESTADO: Pendiente
# TAREA: Tarea 305, ESTADO: Pendiente
# TAREA: Tarea 304, ESTADO: Pendiente
# TAREA: Tarea 238, ESTADO: Pendiente
# TAREA: Tarea 303, ESTADO: Pendiente
# TAREA: Tarea 235, ESTADO: Pendiente
# TAREA: Tarea 242, ESTADO: Pendiente
# TAREA: Tarea 302, ESTADO: Pendiente
# TAREA: Tarea 298, ESTADO: Pendiente
# TAREA: Tarea 301, ESTADO: Pendiente
# TAREA: Tarea 300, ESTADO: Pendiente
# TAREA: Tarea 14, ESTADO: Pendiente
# TAREA: Tarea 243, ESTADO: Pendiente
# TAREA: Tarea 299, ESTADO: Pendiente
# TAREA: Tarea 244, ESTADO: Pendiente
# TAREA: Tarea 10, ESTADO: Pendiente
# TAREA: Tarea 247, ESTADO: Pendiente
# TAREA: Tarea 245, ESTADO: Pendiente
# TAREA: Tarea 246, ESTADO: Pendiente
# TAREA: Tarea 249, ESTADO: Pendiente
# TAREA: Tarea 250, ESTADO: Pendiente
# TAREA: Tarea 29, ESTADO: Pendiente
# TAREA: Tarea 251, ESTADO: Pendiente
# TAREA: Tarea 330, ESTADO: Pendiente
# TAREA: Tarea 288, ESTADO: Pendiente
# TAREA: Tarea 3, ESTADO: Pendiente
# TAREA: Tarea 256, ESTADO: Pendiente
# TAREA: Tarea 208, ESTADO: Pendiente
# TAREA: Tarea 32, ESTADO: Pendiente
# TAREA: Tarea 4, ESTADO: Pendiente
# TAREA: Tarea 240, ESTADO: Pendiente
# TAREA: Tarea 237, ESTADO: Pendiente
# TAREA: Tarea 8, ESTADO: Pendiente
# TAREA: Tarea 22, ESTADO: Pendiente
# TAREA: Tarea 236, ESTADO: Pendiente
# TAREA: Tarea 241, ESTADO: Pendiente
# TAREA: Tarea 19, ESTADO: Pendiente
# TAREA: Tarea 239, ESTADO: Pendiente
# TAREA: Tarea 210, ESTADO: Pendiente
# TAREA: Tarea 27, ESTADO: Pendiente
# TAREA: Tarea 257, ESTADO: Pendiente
# TAREA: Tarea 252, ESTADO: Pendiente
# TAREA: Tarea 234, ESTADO: Pendiente
# TAREA: Tarea 12, ESTADO: Pendiente
# TAREA: Tarea 255, ESTADO: Pendiente
# TAREA: Tarea 23, ESTADO: Pendiente
# TAREA: Tarea 18, ESTADO: Pendiente
# TAREA: Tarea 253, ESTADO: Pendiente
# TAREA: Tarea 500, ESTADO: Pendiente
# TAREA: Tarea 258, ESTADO: Pendiente
# TAREA: Tarea 254, ESTADO: Pendiente
# TAREA: Tarea 21, ESTADO: Pendiente
# TAREA: Tarea 261, ESTADO: Pendiente
# TAREA: Tarea 260, ESTADO: Pendiente
# TAREA: Tarea 31, ESTADO: Pendiente
# TAREA: Tarea 24, ESTADO: Pendiente
# TAREA: Tarea 291, ESTADO: Pendiente
# TAREA: Tarea 267, ESTADO: Pendiente
# TAREA: Tarea 259, ESTADO: Pendiente
# TAREA: Tarea 17, ESTADO: Pendiente
# TAREA: Tarea 292, ESTADO: Pendiente
# TAREA: Tarea 264, ESTADO: Pendiente
# TAREA: Tarea 266, ESTADO: Pendiente
# TAREA: Tarea 263, ESTADO: Pendiente
# TAREA: Tarea 262, ESTADO: Pendiente
# TAREA: Tarea 2, ESTADO: Pendiente
# TAREA: Tarea 265, ESTADO: Pendiente
# TAREA: Tarea 268, ESTADO: Pendiente
# TAREA: Tarea 271, ESTADO: Pendiente
# TAREA: Tarea 269, ESTADO: Pendiente
# TAREA: Tarea 6, ESTADO: Pendiente
# TAREA: Tarea 283, ESTADO: Pendiente
# TAREA: Tarea 270, ESTADO: Pendiente
# TAREA: Tarea 285, ESTADO: Pendiente
# TAREA: Tarea 9, ESTADO: Pendiente
# TAREA: Tarea 7, ESTADO: Pendiente
# TAREA: Tarea 272, ESTADO: Pendiente
# TAREA: Tarea 289, ESTADO: Pendiente
# TAREA: Tarea 276, ESTADO: Pendiente
# TAREA: Tarea 290, ESTADO: Pendiente
# TAREA: Tarea 277, ESTADO: Pendiente
# TAREA: Tarea 15, ESTADO: Pendiente
# TAREA: Tarea 278, ESTADO: Pendiente
# TAREA: Tarea 287, ESTADO: Pendiente
# TAREA: Tarea 274, ESTADO: Pendiente
# TAREA: Tarea 16, ESTADO: Pendiente
# TAREA: Tarea 275, ESTADO: Pendiente
# TAREA: Tarea 273, ESTADO: Pendiente
# TAREA: Tarea 284, ESTADO: Pendiente
# TAREA: Tarea 282, ESTADO: Pendiente
# TAREA: Tarea 280, ESTADO: Pendiente
# TAREA: Tarea 279, ESTADO: Pendiente
# TAREA: Tarea 281, ESTADO: Pendiente
# TAREA: Tarea 286, ESTADO: Pendiente
# TAREA: Tarea 26, ESTADO: Pendiente

# %% [markdown]
# Both exercises will help you improve your code performance optimization skills and give you a better understanding of how different data structures and programming techniques can affect the efficiency of your code.
